# %%
''' Write a program that will determine weather when the value of temperature and humidity is provided by the user.
TEMPERATURE(C) HUMIDITY(%) WEATHER
>= 30 >=90 Hot and Humid >= 30 < 90 Hot <30 >= 90 Cool and Humid <30 <90 Cool '''
# Out:
# ' Write a program that will determine weather when the value of temperature and humidity is provided by the user.\nTEMPERATURE(C) HUMIDITY(%) WEATHER\n>= 30 >=90 Hot and Humid >= 30 < 90 Hot <30 >= 90 Cool and Humid <30 <90 Cool '

# %%
# Take input from user;
t = float(input("Enter Tempurature in degree celsius (°C) : "))
h = float(input("Enter humidity (%)  :"))

# Determine the weather

if t >= 30 and h >= 90:
    print("weather: is hot and humid")
elif t >= 30 and h < 90:
    print("weather: is hot")
elif t <30 and h >= 90:
    print("weather: is cool and humid")
else:
    print("weather: is cool")
# Out:
# Enter Tempurature in degree celsius (°C) :  29
# Enter humidity (%)  : 12
# weather: is cool
