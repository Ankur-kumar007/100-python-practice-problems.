# %%
# Write a program that will give you the sum of 3 digits

# %%
num = input("Enter 3 dights value:")

sum_digits = int(num[0]) + int(num[1]) + int(num[2])

print("sum is:", sum_digits)
# Out:
# Enter 3 dights value: 852
# sum is: 15
