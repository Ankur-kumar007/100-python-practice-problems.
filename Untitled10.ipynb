# %%
# Write a program to find the simple interest when the value of principle,rate of interest and time period is given.

# %%
# Input coordinates:
p = float(input("Enter principal amount :"))
r = float(input("Enter rate of interest :"))
t = float(input("Enter period of time :"))

# Logic where we calculate simple interest:

si = p * r * t / 100

# Display result

print("The simple interest is = ", si)
# Out:
# Enter principal amount : 100000
# Enter rate of interest : 5
# Enter period of time : 5
# The simple interest is =  25000.0
