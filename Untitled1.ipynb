# %%
# Write a program that will convert celsius value to fahrenheit

# %%
celsius = float(input("Enter Tempurature in Celsius"))

fahrenheit = (9/5* celsius + 32)

print(fahrenheit)
# Out:
# Enter Tempurature in Celsius 85
# 185.0
